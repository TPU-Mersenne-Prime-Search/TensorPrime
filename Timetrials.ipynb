# %% [markdown]
# # Unit Testing
#
# This notebook provides a way to run unit tests in Google Colab on TPU hardware. Make sure the `TPU` runtime type is enabled and run the following cells in order.

# %%
import os

branch = 'master' #@param ['master'] {allow-input: true}

'''Load & cd into gdrive for persistent data'''
global path_dir
if not os.path.exists('/content/gdrive/MyDrive/'): # create your own notebook with our code
  print("Google Drive is not mounted at /content/gdrive. You will be prompted to sign in to Google to mount your GDrive.")
  from google.colab import drive
  drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive'


if not os.path.exists('/content/gdrive/MyDrive/GIMPS'):
  print("Creating GIMPS folder...")
  # %mkdir -p GIMPS
# %cd 'GIMPS'

# !git clone https://github.com/TPU-Mersenne-Prime-Search/TensorPrime/ TensorPrime
# %cd TensorPrime
# !git pull
# Out:
# Google Drive is not mounted at /content/gdrive. You will be prompted to sign in to Google to mount your GDrive.
# Mounted at /content/gdrive
# /content/gdrive/MyDrive
# /content/gdrive/MyDrive/GIMPS
# fatal: destination path 'TensorPrime' already exists and is not an empty directory.
# /content/gdrive/MyDrive/GIMPS/TensorPrime
# Already up to date.

# %% [markdown]
# Pull latest code from new branch

# %%
# !git checkout {branch} && git pull
# Out:
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# Already up to date.

# %% [markdown]
# Run tests

# %%
import csv
import time
from math import log2, floor

file = open('/content/known_primes.csv', 'r')
type(file)
csvreader = csv.reader(file)
next(csvreader)

fields = ['Num', 'Exponent', 'Time']
filename = "/content/Timed trials.csv"
with open(filename, 'a') as csvfile:
  csvwriter = csv.writer(csvfile)
  csvwriter.writerow(fields)
#f = open('Timed trials.csv', 'w')

#print(f)
toWrite = []
timed = 0
runs = 0
for row in csvreader:
  #if(runs == 2): break
  x = row[1]
  with open(filename, 'a') as csvfile:
    csvwriter = csv.writer(csvfile)
    x_sig = 2**floor(log2(int(x)))
    start = time.time()
    # !python3 main.py -p $x --siglen $x_sig
    end = time.time()
    timed = (end - start)
    toWrite = [str(runs), str(x), str(timed)]
    csvwriter.writerow(toWrite)
  runs +=1
# Out:
# Testing p=2
# 2022-02-15 22:41:49.000648: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2 tested in 1.7367584705352783 sec: composite
# Testing p=3
# 2022-02-15 22:42:03.839980: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 3 tested in 0.026489973068237305 sec: composite
# Testing p=5
# 2022-02-15 22:42:23.269471: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 5 tested in 1.2543017864227295 sec: probably prime!
# Testing p=7
# 2022-02-15 22:42:41.827949: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 7 tested in 0.0560758113861084 sec: probably prime!
# Testing p=13
# 2022-02-15 22:43:02.489050: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 13 tested in 1.3489093780517578 sec: probably prime!
# Testing p=17
# 2022-02-15 22:43:28.527493: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 17 tested in 1.443690299987793 sec: probably prime!
# Testing p=19
# 2022-02-15 22:44:09.801443: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 19 tested in 0.12920546531677246 sec: probably prime!
# Testing p=31
# 2022-02-15 22:44:36.265150: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 31 tested in 0.23493742942810059 sec: probably prime!
# Testing p=61
# 2022-02-15 22:44:57.020071: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 61 tested in 1.6711406707763672 sec: probably prime!
# Testing p=89
# 2022-02-15 22:45:19.227819: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 89 tested in 1.8446707725524902 sec: probably prime!
# Testing p=107
# 2022-02-15 22:45:41.923891: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 107 tested in 0.7931149005889893 sec: probably prime!
# Testing p=127
# 2022-02-15 22:46:08.452755: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 127 tested in 0.936847448348999 sec: probably prime!
# Testing p=521
# 2022-02-15 22:46:41.255810: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 521 tested in 6.629272222518921 sec: probably prime!
# Testing p=607
# 2022-02-15 22:47:14.395039: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 607 tested in 5.18160080909729 sec: probably prime!
# Testing p=1279
# 2022-02-15 22:47:45.429891: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 1279 tested in 16.155385971069336 sec: probably prime!
# Testing p=2203
# 2022-02-15 22:48:20.373625: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2203 tested in 37.03768849372864 sec: probably prime!
# Testing p=2281
# 2022-02-15 22:49:17.943907: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2281 tested in 33.86353802680969 sec: probably prime!
# Testing p=3217
# 2022-02-15 22:50:09.678607: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 3217 tested in 53.6200647354126 sec: probably prime!
# Testing p=4253
# 2022-02-15 22:51:20.445468: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 4253 tested in 123.50872945785522 sec: probably prime!
# Testing p=4423
# 2022-02-15 22:53:39.872475: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 4423 tested in 127.81353545188904 sec: probably prime!
# Testing p=9689
# 2022-02-15 22:56:01.082321: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 9689 tested in 698.7090244293213 sec: probably prime!
# Testing p=9941
# 2022-02-15 23:07:56.524845: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 9941 tested in 748.4885740280151 sec: probably prime!
# Testing p=11213
# 2022-02-15 23:20:44.263147: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 11213 tested in 887.014732837677 sec: probably prime!
# Testing p=19937
# 2022-02-15 23:36:29.877179: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 19937 tested in 4471.44055223465 sec: probably prime!
# Testing p=21701
# 2022-02-16 00:51:14.655325: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 21701 tested in 5183.881332397461 sec: probably prime!
# Testing p=23209
# 2022-02-16 02:17:55.091681: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 23209 tested in 5814.940692424774 sec: probably prime!
# Testing p=44497
# 2022-02-16 03:55:07.999933: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
